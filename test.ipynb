# %%
import pyarrow.parquet as pq

# %%
pFile = pq.ParquetFile("./7c421ba5-cb2c-4133-8ecd-eeb26014b000.parquet")
train_features = pFile.read().to_pandas()

# %%
train_features
# Out:
#         feature9   feature8  feature10  feature7  feature4  feature13
# 0     -90.159405  41.309334  22.441033   43810.0   61554.0        8.0  \
# 1     -87.205917  31.873946  15.842294  214703.0   36108.0        8.0
# 2    -117.501725  33.752600  20.921839  103689.0   91331.0        8.0
# 3     -84.189655  34.273153  24.667567       NaN       NaN        4.0
# 4     -96.805311        NaN  25.622882       NaN       NaN        6.0
# ...          ...        ...        ...       ...       ...        ...
# 1912  -87.558521  40.847734  23.163368   32038.0   60517.0        5.0
# 1913 -113.085182        NaN  20.658051       NaN   85053.0        6.0
# 1914  -99.708932  31.720351  25.005613  124196.0   79602.0        4.0
# 1915  -77.380536  42.033637  22.038444    1404.0   14861.0        7.0
# 1916  -79.058719  40.265393  21.492534  687276.0   15222.0        5.0
#
#        feature5  feature12  feature15  feature16  feature11  feature1
# ...

# %%
train_features.isna().sum()
# Out:
# feature9     27
# feature8     40
# feature10    33
# feature7     30
# feature4     37
# feature13    23
# feature5     42
# feature12    32
# feature15    34
# feature16    22
# feature11    27
# feature1      0
# feature6     26
# feature14    32
# feature3     28
# feature2      0
# dtype: int64
